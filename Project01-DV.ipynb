# %%
import pandas as pd
import matplotlib.pyplot as plt
df1=pd.read_csv("extract/2013-07 - Citi Bike trip data.csv")
df1
# Out:
#         tripduration         starttime         stoptime  start station id  \
# 0                634   7/1/13 12:00 AM  7/1/13 12:10 AM               164
# 1               1547   7/1/13 12:00 AM  7/1/13 12:25 AM               388
# 2                178   7/1/13 12:01 AM  7/1/13 12:04 AM               293
# 3               1580   7/1/13 12:01 AM  7/1/13 12:27 AM               531
# 4                757   7/1/13 12:01 AM  7/1/13 12:13 AM               382
# 5                861   7/1/13 12:01 AM  7/1/13 12:15 AM               511
# 6                550   7/1/13 12:01 AM  7/1/13 12:11 AM               293
# 7                288   7/1/13 12:02 AM  7/1/13 12:07 AM               224
# 8                766   7/1/13 12:02 AM  7/1/13 12:15 AM               432
# 9                773   7/1/13 12:02 AM  7/1/13 12:15 AM               173
# 10               456   7/1/13 12:02 AM  7/1/13 12:09 AM               146
# 11               632   7/1/13 12:02 AM  7/1/13 12:12 AM               251
# ...

# %%
df1s=df1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df1s
df1s.to_csv(r'Untitled Folder\Sample.csv')

# %%
df2=pd.read_csv("extract/2013-08 - Citi Bike trip data.csv")
df2s=df2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2s
with open('Untitled Folder/Sample.csv', 'a') as f:
    df2s.to_csv(f, header=False)

# %%
df3=pd.read_csv("extract/2013-09 - Citi Bike trip data.csv")
df3s=df3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2s
with open('Untitled Folder/Sample.csv', 'a') as f:
    df3s.to_csv(f, header=False)

# %%
df4=pd.read_csv("extract/2013-10 - Citi Bike trip data.csv")
df4s=df4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df4s
with open('Untitled Folder/Sample.csv', 'a') as f:
    df4s.to_csv(f, header=False)

# %%
df5=pd.read_csv("extract/2013-11 - Citi Bike trip data.csv")
df5s=df5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df5s
with open('Untitled Folder/Sample.csv', 'a') as f:
    df5s.to_csv(f, header=False)

# %%
df6=pd.read_csv("extract/2013-12 - Citi Bike trip data.csv")
df6s=df6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df6s
with open('Untitled Folder/Sample.csv', 'a') as f:
    df6s.to_csv(f, header=False)

# %%
df2013=pd.read_csv("Untitled Folder/Sample.csv")
df2013.columns=['ID','tripduration', 'starttime', 'stoptime', 'start-station-id', 'start-station-name','start-station-latitude','start-station-longitude','end-station-id','end-station-name','end-station-latitude','end-station-longitude','bike-id','user-type','birth-year','gender']

# %%
df2014_1=pd.read_csv("extract/2014-01 - Citi Bike trip data.csv")
df2014_1
# Out:
#         tripduration         starttime          stoptime  start station id  \
# 0                471   1/1/14 12:00 AM   1/1/14 12:07 AM              2009
# 1               1494   1/1/14 12:00 AM   1/1/14 12:25 AM               536
# 2                464   1/1/14 12:03 AM   1/1/14 12:11 AM               228
# 3                373   1/1/14 12:05 AM   1/1/14 12:11 AM               519
# 4                660   1/1/14 12:05 AM   1/1/14 12:16 AM                83
# 5                330   1/1/14 12:05 AM   1/1/14 12:11 AM               422
# 6                261   1/1/14 12:06 AM   1/1/14 12:10 AM               516
# 7                337   1/1/14 12:06 AM   1/1/14 12:12 AM               380
# 8                429   1/1/14 12:07 AM   1/1/14 12:14 AM               296
# 9               1025   1/1/14 12:08 AM   1/1/14 12:25 AM               540
# 10               718   1/1/14 12:09 AM   1/1/14 12:21 AM               263
# ...

# %%
df2014_1s=df2014_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_1s
df2014_1s.to_csv(r'Untitled Folder\Sample2014.csv')

# %%
df2014_2=pd.read_csv("extract/2014-02 - Citi Bike trip data.csv")
df2014_2s=df2014_2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_2s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_2s.to_csv(f, header=False)

# %%
df2014_3=pd.read_csv("extract/2014-03 - Citi Bike trip data.csv")
df2014_3s=df2014_3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_3s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_3s.to_csv(f, header=False)

# %%
df2014_4=pd.read_csv("extract/2014-04 - Citi Bike trip data.csv")
df2014_4s=df2014_4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_4s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_4s.to_csv(f, header=False)

# %%
df2014_5=pd.read_csv("extract/2014-05 - Citi Bike trip data.csv")
df2014_5s=df2014_5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_5s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_5s.to_csv(f, header=False)

# %%
df2014_6=pd.read_csv("extract/2014-06 - Citi Bike trip data.csv")
df2014_6s=df2014_6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_6s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_6s.to_csv(f, header=False)

# %%
df2014_7=pd.read_csv("extract/2014-07 - Citi Bike trip data.csv")
df2014_7s=df2014_7.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_7s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_7s.to_csv(f, header=False)

# %%
df2014_8=pd.read_csv("extract/2014-08 - Citi Bike trip data.csv")
df2014_8s=df2014_8.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_8s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_8s.to_csv(f, header=False)

# %%
df2014_9=pd.read_csv("extract/201409-citibike-tripdata.csv")
df2014_9s=df2014_9.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_9s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_9s.to_csv(f, header=False)

# %%
df2014_10=pd.read_csv("extract/201410-citibike-tripdata.csv")
df2014_10s=df2014_10.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_10s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_10s.to_csv(f, header=False)

# %%
df2014_11=pd.read_csv("extract/201411-citibike-tripdata.csv")
df2014_11s=df2014_11.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_11s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_11s.to_csv(f, header=False)

# %%
df2014_12=pd.read_csv("extract/201412-citibike-tripdata.csv")
df2014_12s=df2014_12.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2014_12s
with open('Untitled Folder/Sample2014.csv', 'a') as f:
    df2014_12s.to_csv(f, header=False)

# %%
df2014=pd.read_csv("Untitled Folder/Sample2014.csv")

# %%
df2015_1=pd.read_csv("extract/201501-citibike-tripdata.csv")
df2015_1s=df2015_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_1s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_1s.to_csv(f, header=True)
df2015_2=pd.read_csv("extract/201502-citibike-tripdata.csv")
df2015_2s=df2015_2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_2s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_2s.to_csv(f, header=False)
df2015_3=pd.read_csv("extract/201503-citibike-tripdata.csv")
df2015_3s=df2015_3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_3s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_3s.to_csv(f, header=False)
df2015_4=pd.read_csv("extract/201504-citibike-tripdata.csv")
df2015_4s=df2015_4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_4s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_4s.to_csv(f, header=False)
df2015_5=pd.read_csv("extract/201505-citibike-tripdata.csv")
df2015_5s=df2015_5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_5s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_5s.to_csv(f, header=False)
df2015_6=pd.read_csv("extract/201506-citibike-tripdata.csv")
df2015_6s=df2015_6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_6s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_6s.to_csv(f, header=False)
df2015_7=pd.read_csv("extract/201507-citibike-tripdata.csv")
df2015_7s=df2015_7.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_7s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_7s.to_csv(f, header=False)
df2015_8=pd.read_csv("extract/201508-citibike-tripdata.csv")
df2015_8s=df2015_8.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_8s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_8s.to_csv(f, header=False)
df2015_9=pd.read_csv("extract/201509-citibike-tripdata.csv")
df2015_9s=df2015_9.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_9s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_9s.to_csv(f, header=False)
df2015_10=pd.read_csv("extract/201510-citibike-tripdata.csv")
df2015_10s=df2015_10.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_10s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_10s.to_csv(f, header=False)
df2015_11=pd.read_csv("extract/201511-citibike-tripdata.csv")
df2015_11s=df2015_11.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_11s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_11s.to_csv(f, header=False)
df2015_12=pd.read_csv("extract/201512-citibike-tripdata.csv")
df2015_12s=df2015_12.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2015_12s
with open('Untitled Folder/Sampled_data2015.csv', 'a') as f:
    df2015_12s.to_csv(f, header=False)

# %%
df2016_1=pd.read_csv("extract/201601-citibike-tripdata.csv")
df2016_1s=df2016_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_1s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_1s.to_csv(f, header=True)
df2016_2=pd.read_csv("extract/201602-citibike-tripdata.csv")
df2016_2s=df2016_2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_2s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_2s.to_csv(f, header=False)
df2016_3=pd.read_csv("extract/201603-citibike-tripdata.csv")
df2016_3s=df2016_3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_3s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_3s.to_csv(f, header=False)
df2016_4=pd.read_csv("extract/201604-citibike-tripdata.csv")
df2016_4s=df2016_4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_4s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_4s.to_csv(f, header=False)
df2016_5=pd.read_csv("extract/201605-citibike-tripdata.csv")
df2016_5s=df2016_5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_5s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_5s.to_csv(f, header=False)
df2016_6=pd.read_csv("extract/201606-citibike-tripdata.csv")
df2016_6s=df2016_6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_6s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_6s.to_csv(f, header=False)
df2016_7=pd.read_csv("extract/201607-citibike-tripdata.csv")
df2016_7s=df2016_7.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_7s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_7s.to_csv(f, header=False)
df2016_8=pd.read_csv("extract/201608-citibike-tripdata.csv")
df2016_8s=df2016_8.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_8s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_8s.to_csv(f, header=False)
df2016_9=pd.read_csv("extract/201609-citibike-tripdata.csv")
df2016_9s=df2016_9.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_9s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_9s.to_csv(f, header=False)
df2016_10=pd.read_csv("extract/201610-citibike-tripdata.csv")
df2016_10s=df2016_10.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_10s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_10s.to_csv(f, header=False)
df2016_11=pd.read_csv("extract/201611-citibike-tripdata.csv")
df2016_11s=df2016_11.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_11s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_11s.to_csv(f, header=False)
df2016_12=pd.read_csv("extract/201612-citibike-tripdata.csv")
df2016_12s=df2016_12.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2016_12s
with open('Untitled Folder/Sampled_data2016.csv', 'a') as f:
    df2016_12s.to_csv(f, header=False)

# %%
df2017_1=pd.read_csv("extract/201701-citibike-tripdata.csv")
df2017_1s=df2017_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_1s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_1s.to_csv(f, header=True)
df2017_2=pd.read_csv("extract/201702-citibike-tripdata.csv")
df2017_2s=df2017_2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_2s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_2s.to_csv(f, header=False)
df2017_3=pd.read_csv("extract/201703-citibike-tripdata.csv")
df2017_3s=df2017_3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_3s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_3s.to_csv(f, header=False)
df2017_4=pd.read_csv("extract/201704-citibike-tripdata.csv")
df2017_4s=df2017_4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_4s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_4s.to_csv(f, header=False)
df2017_5=pd.read_csv("extract/201705-citibike-tripdata.csv")
df2017_5s=df2017_5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_5s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_5s.to_csv(f, header=False)
df2017_6=pd.read_csv("extract/201706-citibike-tripdata.csv")
df2017_6s=df2017_6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_6s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_6s.to_csv(f, header=False)
df2017_7=pd.read_csv("extract/201707-citibike-tripdata.csv")
df2017_7s=df2017_7.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_7s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_7s.to_csv(f, header=False)
df2017_8=pd.read_csv("extract/201708-citibike-tripdata.csv")
df2017_8s=df2017_8.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_8s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_8s.to_csv(f, header=False)
df2017_9=pd.read_csv("extract/201709-citibike-tripdata.csv")
df2017_9s=df2017_9.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_9s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_9s.to_csv(f, header=False)
df2017_10=pd.read_csv("extract/201710-citibike-tripdata.csv")
df2017_10s=df2017_10.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_10s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_10s.to_csv(f, header=False)
df2017_11=pd.read_csv("extract/201711-citibike-tripdata.csv")
df2017_11s=df2017_11.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_11s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_11s.to_csv(f, header=False)
df2017_12=pd.read_csv("extract/201712-citibike-tripdata.csv")
df2017_12s=df2017_12.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2017_12s
with open('Untitled Folder/Sampled_data2017.csv', 'a') as f:
    df2017_12s.to_csv(f, header=False)

# %%
df2018_1=pd.read_csv("extract/201801-citibike-tripdata.csv")
df2018_1s=df2018_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_1s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_1s.to_csv(f, header=True)
df2018_2=pd.read_csv("extract/201802-citibike-tripdata.csv")
df2018_2s=df2018_2.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_2s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_2s.to_csv(f, header=False)
df2018_3=pd.read_csv("extract/201803-citibike-tripdata.csv")
df2018_3s=df2018_3.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_3s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_3s.to_csv(f, header=False)
df2018_4=pd.read_csv("extract/201804-citibike-tripdata.csv")
df2018_4s=df2018_4.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_4s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_4s.to_csv(f, header=False)
df2018_5=pd.read_csv("extract/201805-citibike-tripdata.csv")
df2018_5s=df2018_5.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_5s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_5s.to_csv(f, header=False)
df2018_6=pd.read_csv("extract/201806-citibike-tripdata.csv")
df2018_6s=df2018_6.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_6s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_6s.to_csv(f, header=False)
df2018_7=pd.read_csv("extract/201807-citibike-tripdata.csv")
df2018_7s=df2018_7.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_7s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_7s.to_csv(f, header=False)
df2018_8=pd.read_csv("extract/201808-citibike-tripdata.csv")
df2018_8s=df2018_8.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_8s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_8s.to_csv(f, header=False)
df2018_9=pd.read_csv("extract/201809-citibike-tripdata.csv")
df2018_9s=df2018_9.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_9s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_9s.to_csv(f, header=False)
df2018_10=pd.read_csv("extract/201810-citibike-tripdata.csv")
df2018_10s=df2018_10.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_10s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_10s.to_csv(f, header=False)
df2018_11=pd.read_csv("extract/201811-citibike-tripdata.csv")
df2018_11s=df2018_11.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_11s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_11s.to_csv(f, header=False)
df2018_12=pd.read_csv("extract/201812-citibike-tripdata.csv")
df2018_12s=df2018_12.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2018_12s
with open('Untitled Folder/Sampled_data2018.csv', 'a') as f:
    df2018_12s.to_csv(f, header=False)

# %%
df2019_1=pd.read_csv("extract/201901-citibike-tripdata.csv")
df2019_1s=df2019_1.sample(n=20, frac=None, replace=False, weights=None, random_state=None, axis=None)
df2019_1s
with open('Untitled Folder/Sampled_data2019.csv', 'a') as f:
    df2019_1s.to_csv(f, header=True)
